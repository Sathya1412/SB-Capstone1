# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('listings.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6633 entries, 0 to 6632
# Data columns (total 96 columns):
# id                                  6633 non-null int64
# listing_url                         6633 non-null object
# scrape_id                           6633 non-null int64
# last_scraped                        6633 non-null object
# name                                6633 non-null object
# summary                             6405 non-null object
# space                               5592 non-null object
# description                         6609 non-null object
# experiences_offered                 6633 non-null object
# neighborhood_overview               4716 non-null object
# notes                               4046 non-null object
# transit                             4782 non-null object
# access                              4576 non-null object
# interaction                         4451 non-null object
# house_rules                         4855 non-null object
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  6.633000e+03  6.633000e+03            0.0         0.0             0.0
# mean   1.371588e+07  2.018081e+13            NaN         NaN             NaN
# std    8.751000e+06  2.922095e+00            NaN         NaN             NaN
# min    9.580000e+02  2.018081e+13            NaN         NaN             NaN
# 25%    5.154367e+06  2.018081e+13            NaN         NaN             NaN
# 50%    1.495054e+07  2.018081e+13            NaN         NaN             NaN
# 75%    2.162085e+07  2.018081e+13            NaN         NaN             NaN
# max    2.753014e+07  2.018081e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  6.633000e+03                   0.0          6633.000000
# mean   3.725194e+07                   NaN            45.097995
# std    5.023606e+07                   NaN           188.119805
# ...
